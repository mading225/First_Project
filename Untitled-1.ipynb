# %% [markdown]
# Project Objectives
#
# Analyzing data on the Aviation_Data.csv dataset in order to help the company decide which type of aircrafts to purcahse for commercial and private enterprises.
#
# Identifying the top aircrafts mostly used  in the aircraft  industry and how low risks they have.
#
# Identifying the best performing aircraft that are currently doing well and have low risks for the company to purchase.

# %%
# Importing Necessary python Libraries 
import pandas as pd 
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Accessing our dataframe
# df.head() gives an output of 5 rows by defalution_Data.csv')
df = pd.read_csv("Aviation_Data.csv")
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country Latitude Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States      NaN       NaN          NaN
# 1   BRIDGEPORT, CA  United States      NaN       NaN          NaN
# 2    Saltville, VA  United States  36.9222  -81.8781          NaN
# 3       EUREKA, CA  United States      NaN       NaN          NaN
# 4       Canton, OH  United States      NaN       NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
# Accessing the last 5 rows in the the dataframe
df.tail ()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#             Location        Country Latitude Longitude Airport.Code  \
# 90343  Annapolis, MD  United States      NaN       NaN          NaN
# 90344    Hampton, NH  United States      NaN       NaN          NaN
# 90345     Payson, AZ  United States  341525N  1112021W          PAN
# 90346     Morgan, UT  United States      NaN       NaN          NaN
# 90347     Athens, GA  United States      NaN       NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 90343          NaN  ...          Personal                 NaN
# ...

# %%
# checking the shape of our dataframe 
df.shape
# Out:
# (90348, 31)

# %%
# Checking the columns of the dataframe 
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
# Accesing summarised information of the dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
# Checking for duplicated values in our dataset 
df.duplicated().sum()
# Out:
# 1390

# %%
# Dropping duplicated values 
df.drop_duplicates(inplace=True)

# %%
# Checking if the duplicated values have been dopped 
df.duplicated().sum()
# Out:
# 0

# %%
# checking the shape of our dataset after dropping the duplicated values 
df.shape
# Out:
# (88958, 31)

# %%
# checking for numbe of missing values per column
df.isnull().sum()
# Out:
# Event.Id                     69
# Investigation.Type            0
# Accident.Number              69
# Event.Date                   69
# Location                    121
# Country                     295
# Latitude                  54576
# Longitude                 54585
# Airport.Code              38709
# Airport.Name              36168
# Injury.Severity            1069
# Aircraft.damage            3263
# Aircraft.Category         56671
# Registration.Number        1386
# Make                        132
# Model                       161
# Amateur.Built               171
# Number.of.Engines          6153
# Engine.Type                7146
# FAR.Description           56935
# Schedule                  76376
# Purpose.of.flight          6261
# Air.carrier               72310
# Total.Fatal.Injuries      11470
# Total.Serious.Injuries    12579
# Total.Minor.Injuries      12002
# Total.Uninjured            5981
# Weather.Condition          4561
# Broad.phase.of.flight     27234
# ...

# %%
#Numerical description of the dataset 
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
# Checking the proportionality of missing values 
df.isna().mean()
# Out:
# Event.Id                  0.000776
# Investigation.Type        0.000000
# Accident.Number           0.000776
# Event.Date                0.000776
# Location                  0.001360
# Country                   0.003316
# Latitude                  0.613503
# Longitude                 0.613604
# Airport.Code              0.435138
# Airport.Name              0.406574
# Injury.Severity           0.012017
# Aircraft.damage           0.036680
# Aircraft.Category         0.637053
# Registration.Number       0.015580
# Make                      0.001484
# Model                     0.001810
# Amateur.Built             0.001922
# Number.of.Engines         0.069167
# Engine.Type               0.080330
# FAR.Description           0.640021
# Schedule                  0.858562
# Purpose.of.flight         0.070382
# Air.carrier               0.812856
# Total.Fatal.Injuries      0.128937
# Total.Serious.Injuries    0.141404
# Total.Minor.Injuries      0.134918
# Total.Uninjured           0.067234
# ...

# %% [markdown]
# DATA CLEANING AND ANALYSIS
#
# ---

# %%
# dropping irrelevent columns 
columns_to_drop = [
    'Latitude',
    'Longitude',
    'FAR.Description',
    'Schedule',
    'Air.carrier',
    'Airport.Name',
    'Airport.Code',
    'Registration.Number',
    'Event.Id',
    
    'Publication.Date',
    'Investigation.Type',
    'Accident.Number',
    
    
    

]
df.drop(columns=columns_to_drop, inplace=True)
df.shape
# Out:
# (88958, 19)

# %%
# Feeling in the missing values of the relevant columns 
df['Total.Uninjured'] = df['Total.Uninjured'].fillna(df['Total.Uninjured'].mean())
df['Total.Fatal.Injuries'] = df['Total.Fatal.Injuries'].fillna(df['Total.Fatal.Injuries'].mean())
df['Total.Serious.Injuries'] = df['Total.Serious.Injuries'].fillna(df['Total.Serious.Injuries'].mean()) 
df['Total.Minor.Injuries'] = df['Total.Minor.Injuries'].fillna(df['Total.Minor.Injuries'].mean())


df['Event.Date'] = df['Event.Date'].fillna('unknown')
                                                        

df['Injury.Severity'] = df['Injury.Severity'].fillna(0)
df['Aircraft.Category'] = df['Aircraft.Category'].fillna('unspecified')
df['Amateur.Built'] = df['Amateur.Built'].fillna(0)
df['Number.of.Engines'] = df['Number.of.Engines'].fillna(df['Number.of.Engines'].mean())
df['Engine.Type'] = df['Engine.Type'].fillna(0)
df['Purpose.of.flight'] = df['Purpose.of.flight'].fillna(0)
df['Weather.Condition'] = df['Weather.Condition'].fillna(0) 

df['Model'] = df['Model'].fillna(0)
df['Location'] = df['Location'].fillna(0)
df['Make'] = df['Make'].fillna(0)

df['Country'] = df['Country'].fillna(0)
df['Report.Status'] = df['Report.Status'].fillna(0)
df['Aircraft.damage'] = df['Aircraft.damage'].fillna(0)
df['Make'] = df['Make'].fillna(0)
print(df)
# Out:
#        Event.Date         Location        Country Injury.Severity  \
# 0      1948-10-24  MOOSE CREEK, ID  United States        Fatal(2)
# 1      1962-07-19   BRIDGEPORT, CA  United States        Fatal(4)
# 2      1974-08-30    Saltville, VA  United States        Fatal(3)
# 3      1977-06-19       EUREKA, CA  United States        Fatal(2)
# 4      1979-08-02       Canton, OH  United States        Fatal(1)
# ...           ...              ...            ...             ...
# 90343  2022-12-26    Annapolis, MD  United States           Minor
# 90344  2022-12-26      Hampton, NH  United States               0
# 90345  2022-12-26       Payson, AZ  United States       Non-Fatal
# 90346  2022-12-26       Morgan, UT  United States               0
# 90347  2022-12-29       Athens, GA  United States           Minor
#
#       Aircraft.damage Aircraft.Category                        Make  \
# 0           Destroyed       unspecified                     Stinson
# ...

# %%
# checking if the missing values have been cleaned 
df.isna().sum()
# Out:
# Event.Date                    0
# Location                      0
# Country                       0
# Injury.Severity               0
# Aircraft.damage               0
# Aircraft.Category             0
# Make                          0
# Model                         0
# Amateur.Built                 0
# Number.of.Engines             0
# Engine.Type                   0
# Purpose.of.flight             0
# Total.Fatal.Injuries          0
# Total.Serious.Injuries        0
# Total.Minor.Injuries          0
# Total.Uninjured               0
# Weather.Condition             0
# Broad.phase.of.flight     27234
# Report.Status                 0
# dtype: int64

# %%
# Dropping the Broad.phase.of.flight column 
df = df.dropna(subset = ['Broad.phase.of.flight'])

# %%
# checking if the missing values have been cleaned 
df.isna().sum()
# Out:
# Event.Date                0
# Location                  0
# Country                   0
# Injury.Severity           0
# Aircraft.damage           0
# Aircraft.Category         0
# Make                      0
# Model                     0
# Amateur.Built             0
# Number.of.Engines         0
# Engine.Type               0
# Purpose.of.flight         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Weather.Condition         0
# Broad.phase.of.flight     0
# Report.Status             0
# dtype: int64

# %%
# Checking the info of the data after ceaning 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61724 entries, 0 to 63911
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Date              61724 non-null  object
#  1   Location                61724 non-null  object
#  2   Country                 61724 non-null  object
#  3   Injury.Severity         61724 non-null  object
#  4   Aircraft.damage         61724 non-null  object
#  5   Aircraft.Category       61724 non-null  object
#  6   Make                    61724 non-null  object
#  7   Model                   61724 non-null  object
#  8   Amateur.Built           61724 non-null  object
#  9   Number.of.Engines       61724 non-null  float64
#  10  Engine.Type             61724 non-null  object
#  11  Purpose.of.flight       61724 non-null  object
#  12  Total.Fatal.Injuries    61724 non-null  float64
#  13  Total.Serious.Injuries  61724 non-null  float64
# ...

# %%
# Standardizing the "Make" Column to ensure consistency 
df["Make"] = df["Make"].str.capitalize()

# %%
# Checking the engine type per aircraft cotegory by make 
df[['Engine.Type','Aircraft.Category','Make']].value_counts().head(40)
# Out:
# Engine.Type    Aircraft.Category  Make
# Reciprocating  unspecified        Cessna                            17894
#                                   Piper                              9765
#                                   Beech                              3142
#                Airplane           Cessna                             2483
#                                   Piper                              1257
# Turbo Shaft    unspecified        Bell                               1105
# Reciprocating  unspecified        Mooney                              900
#                                   Grumman                             857
#                                   Bellanca                            754
# Turbo Fan      unspecified        Boeing                              635
# Reciprocating  unspecified        Robinson                            599
#                                   Bell                                539
# ...

# %%
#Number of Engines in specific engine types 
df[['Number.of.Engines','Engine.Type']].value_counts().head(40)
# Out:
# Number.of.Engines  Engine.Type
# 1.000000           Reciprocating    48130
# 2.000000           Reciprocating     4868
# 1.000000           Turbo Shaft       2177
# 2.000000           Turbo Prop        1422
#                    Turbo Fan         1027
# 1.000000           Turbo Prop         783
# 1.146585           Unknown            722
# 0.000000           Unknown            497
# 2.000000           Turbo Jet          369
#                    Turbo Shaft        358
# 3.000000           Turbo Fan          337
# 0.000000           0                  246
# 4.000000           Turbo Fan          203
# 1.146585           0                  124
# 3.000000           Turbo Jet           98
# 1.000000           Turbo Jet           60
# 1.146585           Reciprocating       59
# 4.000000           Reciprocating       46
# 1.000000           Unknown             44
# 4.000000           Turbo Jet           39
#                    Turbo Prop          35
# ...

# %%
# Checking the location with the highest number of incidents 
df['Location'].value_counts().head(10)
# Out:
# ANCHORAGE, AK      432
# MIAMI, FL          197
# ALBUQUERQUE, NM    194
# HOUSTON, TX        192
# CHICAGO, IL        180
# FAIRBANKS, AK      173
# TUCSON, AZ         139
# PHOENIX, AZ        132
# ENGLEWOOD, CO      130
# ORLANDO, FL        129
# Name: Location, dtype: int64

# %%
# Checking the "Make", "Model" which were commonly used 
df[['Make','Model']].value_counts().head(10)
# Out:
# Make    Model
# Cessna  152          2115
#         172          1016
#         172N          975
# Piper   PA-28-140     794
# Cessna  150           664
#         172M          640
#         172P          582
#         150M          534
# Piper   PA-18         527
#         PA-28-180     494
# dtype: int64

# %%
# These are the top 20 aircraft make and model total fatal injuries 
# The code below is showing the number of fatal injuries that occured during the aircraft crash per make and model of the aircraft
make_model_fatalities = df.groupby(['Make', 'Model'])['Total.Fatal.Injuries'].sum().reset_index()
make_model_fatalities = make_model_fatalities.sort_values(by='Total.Fatal.Injuries', ascending=False).head(20)

print("Top 20 Make-Model Combinations by Total Fatal Injuries:")
print(make_model_fatalities)
# Out:
# Top 20 Make-Model Combinations by Total Fatal Injuries:
#                    Make        Model  Total.Fatal.Injuries
# 3035             Cessna          152            480.584568
# 3098             Cessna         172N            460.487521
# 8871              Piper    PA-28-181            368.462730
# 8854              Piper    PA-28-140            338.729081
# 8864              Piper    PA-28-180            285.236992
# 3101             Cessna         172P            276.376936
# 577    Airbus industrie  A300B4-605R            266.000000
# 3096             Cessna         172M            265.503342
# 8863              Piper    PA-28-161            253.532702
# 1303              Beech          A36            245.097047
# 3055             Cessna          172            230.390473
# 2215             Boeing      747-131            230.000000
# 2243             Boeing      747-300            229.000000
# 1680               Bell         206B            225.997716
# ...

# %%
# Visualizing the total fatal injusries using the make and model of the aircraft
#Cessna-152 had the most fata injuries 
make_model_fatalities['Make_Model'] = make_model_fatalities['Make'] +  make_model_fatalities['Model']

plt.figure(figsize=(14, 8))
sns.barplot(x='Make_Model', y='Total.Fatal.Injuries', data=make_model_fatalities, palette='viridis')
plt.xticks(rotation=90, ha='center')
plt.title('Top 20 Make-Model Combinations by Total Fatal Injuries')
plt.xlabel('Aircraft Make - Model')
plt.ylabel('Total Fatal Injuries')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Calculating Incident and Injury Metrics per Aircraft Make
#
# ###
# This is done by Grouping the DataFrame by 'Make' to calculate the total number of incidents, total fatal injuries, total serious injuries, and total minor injuries for each aircraft make. Also, counting the incidents that resulted in 'Destroyed' or 'Substantial' aircraft damage for each make.

# %% [markdown]
# **Explanation**:
# This is done by  calculating the total number of incidents, various injury totals, and the count of 'Destroyed' or 'Substantial' aircraft damage per aircraft make.This is by grouping the DataFrame by 'Make' and applying aggregation functions.

# %%
make_metrics = df.groupby('Make').agg(
    total_incidents=('Make', 'size'), # The size element is counting how many times each manufacturer is appearing in the data set 
    total_fatal_injuries=('Total.Fatal.Injuries', 'sum'),
    total_serious_injuries=('Total.Serious.Injuries', 'sum'),
    total_minor_injuries=('Total.Minor.Injuries', 'sum'),
    incidents_severe_damage=(
        'Aircraft.damage',
        lambda x: ((x == 'Destroyed') | (x == 'Substantial')).sum()
    )
).reset_index()

print(make_metrics.head())
# Out:
#                Make  total_incidents  total_fatal_injuries  \
# 0              1200                1              0.647855
# 1  1977 colfer-chan                1              0.647855
# 2        1st ftr gp                1              1.000000
# 3        2000 mccoy                1              1.000000
# 4       2001 mcgirl                1              0.647855
#
#    total_serious_injuries  total_minor_injuries  incidents_severe_damage
# 0                1.000000              0.357061                        1
# 1                0.279881              1.000000                        1
# 2                0.000000              0.000000                        1
# 3                0.279881              0.357061                        1
# 4                1.000000              0.357061                        1

# %% [markdown]
# The incident and injury metrics have been calculated for each aircraft make, this is done by  computing the fatal injury rate and the severe damage rate for each make. This will involve dividing the total fatal injuries and severe damage incidents by the total number of incidents for each make.

# %%
make_metrics['fatal_injury_rate'] = make_metrics['total_fatal_injuries'] / make_metrics['total_incidents']
make_metrics['severe_damage_rate'] = make_metrics['incidents_severe_damage'] / make_metrics['total_incidents']

print(make_metrics.head())
# Out:
#                Make  total_incidents  total_fatal_injuries  \
# 0              1200                1              0.647855
# 1  1977 colfer-chan                1              0.647855
# 2        1st ftr gp                1              1.000000
# 3        2000 mccoy                1              1.000000
# 4       2001 mcgirl                1              0.647855
#
#    total_serious_injuries  total_minor_injuries  incidents_severe_damage  \
# 0                1.000000              0.357061                        1
# 1                0.279881              1.000000                        1
# 2                0.000000              0.000000                        1
# 3                0.279881              0.357061                        1
# 4                1.000000              0.357061                        1
#
#    fatal_injury_rate  severe_damage_rate
# 0           0.647855                 1.0
# 1           0.647855                 1.0
# 2           1.000000                 1.0
# ...

# %% [markdown]
# **Explanation**:
# Identify the lowest risk aircraft makes, this is done by  first filter out makes with very low number of incidents to ensure the rates are statistically significant. Then,ing calculating  an overall risk score using both 'fatal_injury_rate' and 'severe_damage_rate' and sort the DataFrame to find the top 10 lowest risk makes.

# %%
min_incidents = 10
filtered_make_metrics = make_metrics[make_metrics['total_incidents'] >= min_incidents]

# Creating a composite risk score (e.g., average of normalized rates)
# Normalizing rates to ensure they have similar scale if needed
filtered_make_metrics['overall_risk_score'] = (filtered_make_metrics['fatal_injury_rate'] + filtered_make_metrics['severe_damage_rate']) / 2

# Sorting by overall risk score to find the lowest risk makes
lowest_risk_makes = filtered_make_metrics.sort_values(by='overall_risk_score').head(10)

print("Top 10 Lowest Risk Aircraft Makes based on composite risk score:")
print(lowest_risk_makes[['Make', 'total_incidents', 'fatal_injury_rate', 'severe_damage_rate', 'overall_risk_score']])
# Out:
# Top 10 Lowest Risk Aircraft Makes based on composite risk score:
#                        Make  total_incidents  fatal_injury_rate  \
# 3325                  Raven               86           0.084178
# 312                  Barnes               22           0.058896
# 3571  Saab-scania ab (saab)               36           0.225734
# 297           Balloon works              136           0.138461
# 4099       Thunder and colt               23           0.156149
# 1146                Dornier               22           0.235584
# 673                 Cameron               49           0.298936
# 24                    Adams               23           0.202081
# 67                 Aerostar               85           0.344151
# 3736         Short brothers               33           0.372597
#
#       severe_damage_rate  overall_risk_score
# 3325            0.511628            0.297903
# 312             0.545455            0.302175
# 3571            0.388889            0.307311
# ...

# %% [markdown]
# **Reasoning**:
# To compare the risk by purpose of flight, the df_low_risk_makes' DataFrame should include only 'Personal' and 'Business' flights, as these are the primary categories of interest for the project objectives. This will prepare the data for further aggregation and risk calculation based on these specific purposes of flight.

# %%
# 1. Getting  the list of the top 10 safest makes from the summary table
safe_makes = lowest_risk_makes['Make'].unique()

df_low_risk_data = df[df['Make'].isin(safe_makes)]

# 2 filtering for Business and Personal flight purposes
df_low_risk_purpose = df_low_risk_data[df_low_risk_data['Purpose.of.flight'].isin(['Business', 'Personal'])]

# 3. Checking results
print(df_low_risk_purpose['Purpose.of.flight'].value_counts())
# Out:
# Personal    259
# Business     42
# Name: Purpose.of.flight, dtype: int64

# %% [markdown]
# ### Observation on Purpose of Flight
#
# Among the 'lowest_risk_makes' identified, 'Personal' flights have a lower risk compared to the ('commercial' aka 'Business') in the 'Purpose.of.flight' column within the filtered 'df_low_risk_purpose' DataFrame.

# %%
# Calculating incident and injury matrices for these flights within low risk aircraft make
purpose_flight_metrics = df_low_risk_purpose.groupby(['Make', 'Purpose.of.flight']).agg(
    total_incidents=('Make', 'size'),
    total_fatal_injuries=('Total.Fatal.Injuries', 'sum'),
    total_serious_injuries=('Total.Serious.Injuries', 'sum'),
    total_minor_injuries=('Total.Minor.Injuries', 'sum'),
    incidents_severe_damage=(
        'Aircraft.damage',
        lambda x: ((x == 'Destroyed') | (x == 'Substantial')).sum()
    )
).reset_index()

purpose_flight_metrics['fatal_injury_rate'] = purpose_flight_metrics['total_fatal_injuries'] / purpose_flight_metrics['total_incidents']
purpose_flight_metrics['severe_damage_rate'] = purpose_flight_metrics['incidents_severe_damage'] / purpose_flight_metrics['total_incidents']

print("Risk Metrics by Purpose of Flight for Low-Risk Aircraft Makes:")
print(purpose_flight_metrics.sort_values(by='fatal_injury_rate').head(10))
# Out:
# Risk Metrics by Purpose of Flight for Low-Risk Aircraft Makes:
#                      Make Purpose.of.flight  total_incidents  \
# 0                   Adams          Business                3
# 14         Short brothers          Business                1
# 13  Saab-scania ab (saab)          Personal                1
# 6                  Barnes          Business                1
# 8                 Cameron          Business                4
# 11                  Raven          Business                9
# 7                  Barnes          Personal               17
# 12                  Raven          Personal               56
# 4           Balloon works          Business               10
# 5           Balloon works          Personal               84
#
#     total_fatal_injuries  total_serious_injuries  total_minor_injuries  \
# 0               0.000000                5.000000              2.000000
# 14              0.000000                0.000000              2.000000
# ...

# %% [markdown]
# Visualizing the overall risk of the top 10 lowest risk aircraft makes, using a  bar plot showing their 'overall_risk_score'. This will provide a clear visual representation of their risk levels.

# %%
plt.figure(figsize=(12, 7))
sns.barplot(x='Make', y='overall_risk_score', data=lowest_risk_makes.sort_values(by='overall_risk_score', ascending=True))
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Lowest Risk Aircraft Makes by Overall Risk Score')
plt.xlabel('Aircraft Make')
plt.ylabel('Overall Risk Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing Lowest Risk Aircraft Makes (Fatal Injury Rate)

# %%
# creating a bar plot/ graph displaying the top 10 aircraft makes with the lowest ' fatal injury rate'
plt.figure(figsize=(12, 7))
sns.barplot(x='Make', y='fatal_injury_rate', data=lowest_risk_makes.sort_values(by='fatal_injury_rate', ascending=True))
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Lowest Risk Aircraft Makes by Fatal Injury Rate')
plt.xlabel('Aircraft Make')
plt.ylabel('Fatal Injury Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing Lowest Risk Aircraft Makes (Severe Damage Rate)

# %% [markdown]
# **Reasoning**:
# Visualizing the top 10 lowest risk aircraft makes based on their 'severe_damage_rate', this is done by creating a bar plot using the 'lowest_risk_makes' DataFrame, sorting it by 'severe_damage_rate' in ascending order.

# %%
#The top 10 lowest risk aircraft makes with the lowest severe Damage rate
plt.figure(figsize=(12, 7))
sns.barplot(x='Make', y='severe_damage_rate', data=lowest_risk_makes.sort_values(by='severe_damage_rate', ascending=True))
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Lowest Risk Aircraft Makes by Severe Damage Rate')
plt.xlabel('Aircraft Make')
plt.ylabel('Severe Damage Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing Lowest Risk Aircraft Makes (Severe Damage Rate)

# %% [markdown]
# **Reasoning**:
# Visualizing the top 10 lowest risk aircraft makes based on their 'severe_damage_rate', this is done by creating a bar plot using the 'lowest_risk_makes' DataFrame, sorting it by 'severe_damage_rate' in ascending order.

# %%
# Top 10 lowewst risk aircraft makes 
df['Make'].value_counts().head(10)
# Out:
# Cessna      20710
# Piper       11156
# Beech        3974
# Bell         1868
# Boeing       1154
# Grumman      1050
# Mooney       1018
# Bellanca      863
# Robinson      741
# Hughes        736
# Name: Make, dtype: int64

# %% [markdown]
# #The top 10 most common makes in our 'Make' column in the dataset

# %%
#Generating the top 10 most 'Makes' in the "Make" column  
most_common_makes = df['Make'].value_counts().head(10)

plt.figure(figsize=(12, 7))
sns.barplot(x=most_common_makes.index, y=most_common_makes.values, palette='viridis')
plt.title('Top 10 Most Commonly Used Aircraft Makes')
plt.xlabel('Aircraft Make')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Calculati Incident and Injury Metrics per Aircraft Make

# %% [markdown]
# **Reasoning**:
# To calculate the incident and injury metrics for each aircraft make, group the DataFrame `df` by the 'Make' column and apply aggregation functions to count incidents, sum injuries, and count severe damage incidents.Then use a lambda function to calculate the 'incidents_severe_damage' correctly.

# %%
make_metrics = df.groupby('Make').agg(
    total_incidents=('Make', 'size'), # The size element is counting how many times each manufacturer is appearing in the data set
    total_fatal_injuries=('Total.Fatal.Injuries', 'sum'),
    total_serious_injuries=('Total.Serious.Injuries', 'sum'),
    total_minor_injuries=('Total.Minor.Injuries', 'sum'),
    incidents_severe_damage=(
        'Aircraft.damage',
        lambda x: ((x == 'Destroyed') | (x == 'Substantial')).sum()
    )
).reset_index()

print(make_metrics.head())
# Out:
#                Make  total_incidents  total_fatal_injuries  \
# 0              1200                1              0.647855
# 1  1977 colfer-chan                1              0.647855
# 2        1st ftr gp                1              1.000000
# 3        2000 mccoy                1              1.000000
# 4       2001 mcgirl                1              0.647855
#
#    total_serious_injuries  total_minor_injuries  incidents_severe_damage
# 0                1.000000              0.357061                        1
# 1                0.279881              1.000000                        1
# 2                0.000000              0.000000                        1
# 3                0.279881              0.357061                        1
# 4                1.000000              0.357061                        1

# %% [markdown]
# ## Calculating Risk Rates per Aircraft Make

# %% [markdown]
# **Reasoning**:
# To calculate the risk rates per aircraft make, the make_marices is  filtered  for makes with more than 50 incidents, then computed to  the 'fatal_injury_rate' and 'severe_damage_rate' for these filtered makes, and finally display the head of the resulting DataFrame.

# %%
min_incidents_threshold = 50
filtered_make_metrics = make_metrics[make_metrics['total_incidents'] > min_incidents_threshold].copy()

filtered_make_metrics['fatal_injury_rate'] = filtered_make_metrics['total_fatal_injuries'] / filtered_make_metrics['total_incidents']
filtered_make_metrics['severe_damage_rate'] = filtered_make_metrics['incidents_severe_damage'] / filtered_make_metrics['total_incidents']

print(filtered_make_metrics.head())
# Out:
#               Make  total_incidents  total_fatal_injuries  \
# 39  Aero commander              331            199.153482
# 55         Aeronca              468            141.236992
# 63    Aerospatiale              321            199.505627
# 67        Aerostar               85             29.252813
# 91     Air tractor              516            158.347576
#
#     total_serious_injuries  total_minor_injuries  incidents_severe_damage  \
# 39               80.594627             94.353631                      324
# 55              134.912358            166.923099                      462
# 63              141.635463            194.925386                      277
# 67               72.798806             63.070040                       46
# 91               90.982089            142.346770                      506
#
#     fatal_injury_rate  severe_damage_rate
# 39           0.601672            0.978852
# 55           0.301788            0.987179
# ...

# %% [markdown]
# ## Visualizing Lowest Risk Aircraft Makes (Fatal Injury Rate)

# %%
# Lowest Risk Aircraft makes based on the top 10 fatal injury rate 
plt.figure(figsize=(12, 7))
sns.barplot(x='Make', y='fatal_injury_rate', data=filtered_make_metrics.sort_values(by='fatal_injury_rate', ascending=True).head(10))
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Lowest Risk Aircraft Makes by Fatal Injury Rate')
plt.xlabel('Aircraft Make')
plt.ylabel('Fatal Injury Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# #  The top 10 lowest risk aircraft makes based on their 'severe_damage_rate

# %%
# Top 10 on severe damage rate 
plt.figure(figsize=(12, 7))
sns.barplot(x='Make', y='severe_damage_rate', data=filtered_make_metrics.sort_values(by='severe_damage_rate', ascending=True).head(10))
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Lowest Risk Aircraft Makes by Severe Damage Rate')
plt.xlabel('Aircraft Make')
plt.ylabel('Severe Damage Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparing Risk by Purpose of Flight for Key Aircraft Makes
#
#
# # Analyzing  and visualizing the fatal injury rates and severe damage rates for the identified low-risk aircraft makes, specifically comparing incidents categorized as 'Personal' versus 'Business' purposes of flight. This will help inform purchasing decisions for different enterprise types.

# %% [markdown]
# **Explanation**:
# To visualize the fatal injury rates by aircraft make and purpose of flight, I will create a grouped bar chart using the 'purpose_flight_metrics' DataFrame. This will allow for a comparison between 'Personal' and 'Business' flights.

# %%
#Comparing risk by purpose of flight (personal and Business) for key aircraft makes 
plt.figure(figsize=(14, 8))
sns.barplot(x='Make', y='fatal_injury_rate', hue='Purpose.of.flight', data=purpose_flight_metrics, palette='magma')
plt.xticks(rotation=45, ha='right')
plt.title('Fatal Injury Rate by Aircraft Make and Purpose of Flight (Personal vs. Business)')
plt.xlabel('Aircraft Make')
plt.ylabel('Fatal Injury Rate')
plt.tight_layout()
plt.show()

# %%
# Visualizing severe damage rate by Aircraft Make and purpose of flight 
plt.figure(figsize=(14, 8))
sns.barplot(x='Make', y='severe_damage_rate', hue='Purpose.of.flight', data=purpose_flight_metrics, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.title('Severe Damage Rate by Aircraft Make and Purpose of Flight (Personal vs. Business)')
plt.xlabel('Aircraft Make')
plt.ylabel('Severe Damage Rate')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Reccommended Aircraft Makes for Private / Personal Enterprises
# ## The Lowest Risk Aircraft Makes For Personal/Private Enterprises
#
# ### Summary of Findings:
#
# 1.  **Top 10 Lowest Risk Aircraft Makes**: The analysis identified the following aircraft makes as having the lowest overall risk scores (a composite of fatal injury rate and severe damage rate) based on a threshold of at least 10 incidents:
#     *   Saab-scania ab (saab)
#     *   Raven
#     *   Barnes
#     *   Balloon works
#     *   Dornier
#     *   Thunder and colt
#     *   Adams
#     *   Cameron
#
#     *   Aerostar
#
#
# 3.  **'Personal' Flight Risk Profile**: The `personal_flight_metrics` DataFrame shows the fatal injury rates and severe damage rates specifically for 'Personal' flights among these low-risk makes.
#
# ### Recommendations for personal /private use:
#
#
#
# *   **For Private/Personal Use**: The makes identified as 'lowest_risk_makes' (e.g., **Saab-scania ab (saab), Raven, Barnes, Balloon works**) demonstrate lower overall risk scores. Companies looking to acquire aircraft for private use (which aligns with the available data for these makes) should consider these manufacturers.

# %% [markdown]
# ## Reccommended Aircraft Makes For Commercial Puposes
# ## The Lowest Aircraft Risk Makes For 'Business' / 'Commercial' Enterprises
#
# ### Summary of the findings:
#
# 1.  **Top 5 Lowest Aircraft Makes for Based on the severe damage rate and Total Fatal Injury Rates** :The analysis identified the following aircraft makes as having the lowest overall risk
#
# * Adams
# * Aerostar
# * Cameron
# * Raven
# * Balloon works

# %% [markdown]
# ##  Reccomendations for the Aircaft Makes the company should purchase
#
# 1. You can purhase these aircraft makes for either personal or  commercial use:
#  * Adams
#  * Aerstar
#  * Raven
#
#  ## These are recommended because they have the lowest severe damage and Fatal injuries

# %% [markdown]
# ## Note:
#
# 1. Thunder and Colt has low risk or severe damages but has a high risk of total Fatal Injuries, hence it's unreccommended as for either private or commercial purposes
